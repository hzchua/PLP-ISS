# %%
import pandas as pd
import numpy as np
from random import sample 
from scipy.sparse import issparse
from scipy.sparse import csr_matrix
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics.pairwise import euclidean_distances

# %%
# Need to first import the demolib file
from demolib import mapdata
from demolib import getRecommendations_UU
from demolib import getRecommendations_II
from demolib import sparsity
from demolib import predictRatings
from demolib import getitemsimsmatrix
from demolib import pearsonsim
from demolib import cosinesim
from demolib import euclidsim
from demolib import wtavg
from demolib import makeRatingsMatrix

# %%
file = "df_CA_Summarization_filtered.csv"
ratings_dfFull = pd.read_csv(file)

# %%
ratings_dfFull.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'gPlusUserId', 'closed', 'gps', 'name',
#        'phone', 'price', 'gPlusPlaceId', 'rating', 'reviewText', 'reviewCount',
#        'userCount', 'loc', 'cleaned_review', 'cleaned_summary',
#        'cleaned_education', 'cleaned_address', 'cleaned_hours',
#        'cleaned_categories', 'cleaned_jobs', 'sentiment_VADER'],
#       dtype='object')

# %%
ratings_df=ratings_dfFull[['gPlusUserId','name','rating']]
ratings_df.columns = ['user_id','item_id','rating']
print(ratings_df.shape)
ratings_df[0:6]
# Out:
# (954, 3)
#         user_id                          item_id  rating
# 0  1.002152e+20                         Tamarine     5.0
# 1  1.019804e+20                        BAR CRUDO     5.0
# 2  1.029165e+20                     Bar Agricole     5.0
# 3  1.060633e+20  Cat and Fiddle Pub & Restaurant     4.0
# 4  1.074869e+20                       Cafe Flore     4.0
# 5  1.038638e+20            Stout Burgers & Beers     5.0

# %%
def mapdata(ratings_df):
  ratings_df["item_id"] = ratings_df["item_id"].astype(str)
  ratings_df["user_id"] = ratings_df["user_id"].astype(str)
  ratings_df["rating"]  = ratings_df["rating"].values.astype(np.float32)
  user_ids = np.sort(ratings_df["user_id"].unique()).tolist()
  umap = {x: i for i, x in enumerate(user_ids)}
  item_ids = np.sort(ratings_df["item_id"].unique()).tolist()
  imap = {x: i for i, x in enumerate(item_ids)}
  ratings_df["user_id"] = ratings_df["user_id"].map(umap) # swap userid for user index
  ratings_df["item_id"] = ratings_df["item_id"].map(imap) # swap itemid for item index
  return ratings_df, umap, imap

# %%
# define function to convert the rating events into a (dense) ratings matrix
def makeRatingsMatrix(ratings_df):
  ratings_df, umap, imap = mapdata(ratings_df)
  ratmatrix = pd.pivot_table(ratings_df, index=['user_id'], columns=['item_id'], values=['rating'],aggfunc=[np.mean]).values
  return ratmatrix, umap, imap

# %%
# create the (dense) ratings matrix 
ratmatrix, umap, imap = makeRatingsMatrix(ratings_df)
print("user map=", umap)
print("item map=", imap)
print("mapped rating events=\n",ratings_df[0:5])  # to show that the ratings events have been mapped
print("ratings matrix=\n",ratmatrix)
# Out:
# user map= {'100027298100000000000': 0, '100064964300000000000': 1, '100071173100000000000': 2, '100149874600000000000': 3, '100167615300000000000': 4, '100187800700000000000': 5, '100188791600000000000': 6, '100191427200000000000': 7, '100195583100000000000': 8, '100203282600000000000': 9, '100215158900000000000': 10, '100219691400000000000': 11, '100226390700000000000': 12, '100247204500000000000': 13, '100330736800000000000': 14, '100334069800000000000': 15, '100343120700000000000': 16, '100365917800000000000': 17, '100392313900000000000': 18, '100399962200000000000': 19, '100433794300000000000': 20, '100445685400000000000': 21, '100452823500000000000': 22, '100462082800000000000': 23, '100462360000000000000': 24, '100487661000000000000': 25, '100496607900000000000': 26, '100508952600000000000': 27, '100516137400000000000': 28, '100516882800000000000': 29, '100555162400000000000': 30, '100587872100000000000': 31, '100641666600000000000': 32, '100643056300000000000': 33, '100646294100000000000': 34, '100659665700000000000': 35, '100662568300000000000': 36, '100685095400000000000': 37, '100717247000000000000': 38, '100780259400000000000': 39, '100782171200000000000': 40, '100792150800000000000': 41, '100792506900000000000': 42, '100809208700000000000': 43, '100831171700000000000': 44, '100850473700000000000': 45, '100870342600000000000': 46, '100885346200000000000': 47, '100937245200000000000': 48, '100961289000000000000': 49, '100982599100000000000': 50, '100991220400000000000': 51, '101033675200000000000': 52, '101038793100000000000': 53, '101047840900000000000': 54, '101069509200000000000': 55, '101111725100000000000': 56, '101114112700000000000': 57, '101120918300000000000': 58, '101204775400000000000': 59, '101217844500000000000': 60, '101230245000000000000': 61, '101230318100000000000': 62, '101270910800000000000': 63, '101292908500000000000': 64, '101325873200000000000': 65, '101337911900000000000': 66, '101345352400000000000': 67, '101372943500000000000': 68, '101385142800000000000': 69, '101388230600000000000': 70, '101392794300000000000': 71, '101397674200000000000': 72, '101405332100000000000': 73, '101457505700000000000': 74, '101467456800000000000': 75, '101470318000000000000': 76, '101511807200000000000': 77, '101556595000000000000': 78, '101566337500000000000': 79, '101590160300000000000': 80, '101640091200000000000': 81, '101654133400000000000': 82, '101657371000000000000': 83, '101686790400000000000': 84, '101697554800000000000': 85, '101721068100000000000': 86, '101730787400000000000': 87, '101778351100000000000': 88, '101789993400000000000': 89, '101826991800000000000': 90, '101840590100000000000': 91, '101842330800000000000': 92, '101848915800000000000': 93, '101857300900000000000': 94, '101874818600000000000': 95, '101876934000000000000': 96, '101889210100000000000': 97, '101899411600000000000': 98, '101953659300000000000': 99, '101958783300000000000': 100, '101980361100000000000': 101, '102001524600000000000': 102, '102027147700000000000': 103, '102041673500000000000': 104, '102052245500000000000': 105, '102055550100000000000': 106, '102108716600000000000': 107, '102139978400000000000': 108, '102152728500000000000': 109, '102172401900000000000': 110, '102199470600000000000': 111, '102201014700000000000': 112, '102217125700000000000': 113, '102220200000000000000': 114, '102223279800000000000': 115, '102233141400000000000': 116, '102262473700000000000': 117, '102297172400000000000': 118, '102307743900000000000': 119, '102346745200000000000': 120, '102358209400000000000': 121, '102372880600000000000': 122, '102381449500000000000': 123, '102397052100000000000': 124, '102401708600000000000': 125, '102404244100000000000': 126, '102412116000000000000': 127, '102418452400000000000': 128, '102440997800000000000': 129, '102451193300000000000': 130, '102506861700000000000': 131, '102509936900000000000': 132, '102512364700000000000': 133, '102525570600000000000': 134, '102550604900000000000': 135, '102564701200000000 ...
# item map= {"Aldo's Harbor Restaurant": 0, "Aliki's Greek Taverna": 1, 'Aperto': 2, 'Asha Moroccan Mediterranean Kitchen': 3, 'Asia De Cuba': 4, 'Axis Cafe & Gallery': 5, 'B Street & Vine': 6, 'B*Star': 7, 'BAR CRUDO': 8, "BJ's Restaurant & Brewhouse": 9, 'Baja Sonora': 10, 'Bar Agricole': 11, 'Bell Tower': 12, "Bill's Cafe": 13, "Bill's Caf̩": 14, 'Bistro Maxine': 15, 'Black Bear Diner': 16, "Bludso's BBQ": 17, 'Blue Bayou': 18, 'Blue Danube Coffee House': 19, 'Blue Fig': 20, 'Boudin Bakery Caf̩': 21, 'Breakfast Club Diner': 22, 'Bruxie': 23, 'Buca di Beppo - Sacramento': 24, "Buddy's Bites and Brews": 25, 'Buffalo Wild Wings': 26, 'Bumble': 27, 'Burgers and Brew': 28, 'By-Th-Bucket': 29, "Cafe 50's": 30, 'Cafe Flore': 31, 'Cafe Golo': 32, 'Cafe Jacqueline': 33, 'Canteen': 34, 'Canton Seafood & Dim Sum Restaurant': 35, 'Capitol Garage': 36, 'Carnation Cafe': 37, "Carolyn's Cafe": 38, 'Casa De Bandini': 39, 'Casa De Reyes': 40, 'Castaway Restaurant': 41, 'Cat and Fiddle Pub & Restaurant': 42, 'Central Market': 43, 'Cha -Ya Restaurant': 44, 'Chambers': 45, "Charli Marrone's Italian Bar and Grill": 46, 'Chart House': 47, "Chili's Grill & Bar": 48, 'Claim Jumper': 49, 'Comstock Saloon': 50, "Cooper's Pub & Restaurant": 51, "Corky's Kitchen & Bakery": 52, 'Country Gourmet Restaurants': 53, 'Crepevine': 54, "Crow's Nest Restaurant": 55, 'Culichi Town': 56, 'D J Coffee Shop': 57, 'Daily Grill': 58, "Dave & Buster's": 59, 'Delancey Street Restaurant': 60, "Denica's Real Food Kitchen": 61, "Denny's": 62, 'Dojima Ann': 63, "Doria's Haus of Pizza": 64, 'Duboce Park Cafe': 65, 'El Burrito Express 2': 66, 'En': 67, 'Escape From New York Pizza': 68, 'Ethel Reds Chop House': 69, 'Extraordinary Desserts': 70, 'Fahrenheit Restaurant & Lounge': 71, 'Fat Lady': 72, 'First Awakenings': 73, 'First Street AleHouse': 74, 'Five Guys Burgers and Fries': 75, "Frankie and Lola's front Street Cafe": 76, "Fratelli's Italian Kitchen": 77, "Gianni's Pizza": 78, 'Golden Corral': 79, 'Gourmet Haus Staudt': 80, 'Great Eastern Restaurant': 81, 'Guerilla Cafe': 82, 'Hard Rock Cafe': 83, 'Hill Street Cafe': 84, "Hodel's Country Dining": 85, 'Home Restaurant': 86, 'Hong Kong Saigon Restaurant': 87, 'Hops & Hominy': 88, 'In-N-Out Burger': 89, "Jake's Hana Sushi": 90, "Javier's": 91, "Jeffrey's Hamburgers": 92, "Jim's Coffee Shop": 93, "Jocko's": 94, "Joe's Crab Shack Ventura": 95, "Johnny Garlic's": 96, "Jongewaard's Bake n Broil": 97, 'K Sandwiches': 98, 'Kabob Curry': 99, 'Katella Deli-Restaurant': 100, 'Kingfish Restaurant': 101, 'KoKo Beach': 102, 'La Note Restaurant Provencal': 103, 'Lazy Dog Restaurant & Bar': 104, 'Lido Pizza': 105, 'Liliya China Bistro': 106, "Linnaea's Cafe": 107, 'Local Habit': 108, 'Long Beach Cafe': 109, "Lori's Diner": 110, 'Los Cubanos Restaurant': 111, "Lou & Mickey's": 112, 'Luce Restaurant': 113, 'Mad Dog in the Fog': 114, 'Malabar': 115, "Mario's De La Mesa Restaurant": 116, 'Marlowe': 117, 'Matching Half Cafe': 118, 'Maverick': 119, "McDonald's": 120, 'Mezcal': 121, 'Milk': 122, 'Millbrae Pancake House': 123, 'Minako Organic Japanese Restaurant': 124, 'Misoya Ramen': 125, 'Mizu Sushi Bar & Grill': 126, "Mo's Egg House": 127, 'Monte Carlo Deli': 128, 'Moo Creamery LLC': 129, "Morocco's Restaurant Mountain View": 130, "Mrs Olson's Coffee Hut": 131, 'Musso & Frank Grill': 132, 'Mustards Grill': 133, 'Naglee Park Garage': 134, "Naja's Place": 135, 'Napoli Pizzeria & Italian Food': 136, 'Naschmarkt Restaurant': 137, 'Ocean Avenue Seafood': 138, 'Ocha Tea Cafe & Restaurant': 139, 'Old California Coffee House and Eatery': 140, 'Olea': 141, 'Olive Cafe': 142, 'Oola Restaurant & Bar': 143, 'Orange County Mining Co': 144, 'Orochon Ramen': 145, "Orphan Andy's": 146, 'Outback Steakhouse': 147, 'Palm Restaurant': 148, 'Panera Bread': 149, 'Parkside Cafe': 150, "Pepe Delgado's Mexican Restaurant": 151, 'Pinkberry - San Francisco Union Square': 152, 'Pizza Nova': 153, 'Pizzeria Luigi': 154, "Pluto's": 155, "Pocket 8's Sushi & Grill": 156, 'Po ...
# mapped rating events=
#     user_id  item_id  rating
# 0       10      221     5.0
# 1      101        8     5.0
# 2      155       11     5.0
# 3      336       42     4.0
# 4      405       31     4.0
# ratings matrix=
#  [[nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
# select a specific user and get their ratings
targetname = "100215158900000000000"
targetrats = ratmatrix[umap[targetname],] 
targetrats
# Out:
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         5., nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan], dtype=float32)

# %%
# Find the number users with different reviews
numberCountUser=ratings_df.groupby(["user_id"])["user_id"].count().rename('count')
countDf=ratings_df[["user_id"]]
countDf["count"]=numberCountUser

#numberCountUser.columns=["UserId","Count"]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
countDf=pd.DataFrame(numberCountUser)

# %%
countDf.sort_values(by='count',ascending=False)
# Out:
#               count
# user_id
# 1.104490e+20      7
# 1.088672e+20      7
# 1.138995e+20      6
# 1.111152e+20      6
# 1.096830e+20      6
# ...             ...
# 1.052848e+20      1
# 1.052965e+20      1
# 1.053083e+20      1
# 1.053103e+20      1
# 1.146634e+20      1
#
# [811 rows x 1 columns]

# %%
countDf[countDf["count"]>1].count()
# Out:
# count    94
# dtype: int64
